# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from sklearn import datasets
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)

# %%
n_pts = 500 
X, y = datasets.make_circles(n_samples = n_pts, random_state = 123, noise = 0.1, factor = 0.2)

# %%
plt.scatter(X[y == 0,0], X[y ==0, 1])
plt.scatter(X[y == 1,0], X[y ==1, 1])

# %%
model = Sequential()
model.add(Dense(4, input_shape = (2,), activation = 'sigmoid'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(Adam(lr = 0.01), 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(x=X, y=y, verbose = 1, batch_size = 20, epochs = 60, shuffle = 'true')
# Out:
# Epoch 1/60
# 500/500 [==============================] - 0s 568us/step - loss: 0.6959 - accuracy: 0.5100
# Epoch 2/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.6937 - accuracy: 0.6200
# Epoch 3/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6925 - accuracy: 0.5140
# Epoch 4/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.6916 - accuracy: 0.6780
# Epoch 5/60
# 500/500 [==============================] - 0s 58us/step - loss: 0.6905 - accuracy: 0.6300
# Epoch 6/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.6890 - accuracy: 0.3620
# Epoch 7/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6865 - accuracy: 0.6460
# Epoch 8/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6838 - accuracy: 0.6740
# Epoch 9/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6795 - accuracy: 0.7580
# Epoch 10/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6733 - accuracy: 0.7980
# Epoch 11/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6658 - accuracy: 0.8400
# Epoch 12/60
# 500/500 [==============================] - 0s 64us/step - loss: 0.6545 - accuracy: 0.8600
# Epoch 13/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.6418 - accuracy: 0.8780
# Epoch 14/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.6266 - accuracy: 0.8920
# Epoch 15/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.6073 - accuracy: 0.8800
# Epoch 16/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.5879 - accuracy: 0.8700
# Epoch 17/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.5672 - accuracy: 0.8840
# Epoch 18/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.5438 - accuracy: 0.8560
# Epoch 19/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.5216 - accuracy: 0.8860
# Epoch 20/60
# 500/500 [==============================] - 0s 68us/step - loss: 0.4972 - accuracy: 0.8880
# Epoch 21/60
# 500/500 [==============================] - 0s 70us/step - loss: 0.4747 - accuracy: 0.8880
# Epoch 22/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.4520 - accuracy: 0.8920
# Epoch 23/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.4297 - accuracy: 0.8920
# Epoch 24/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.4089 - accuracy: 0.9040
# Epoch 25/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.3895 - accuracy: 0.9000
# Epoch 26/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.3698 - accuracy: 0.9140
# Epoch 27/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.3513 - accuracy: 0.9100
# Epoch 28/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.3342 - accuracy: 0.9160
# Epoch 29/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.3173 - accuracy: 0.9180
# Epoch 30/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.3019 - accuracy: 0.9220
# Epoch 31/60
# 500/500 [==============================] - 0s 58us/step - loss: 0.2869 - accuracy: 0.9240
# Epoch 32/60
# 500/500 [==============================] - 0s 58us/step - loss: 0.2732 - accuracy: 0.9320
# Epoch 33/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.2604 - accuracy: 0.9420
# Epoch 34/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.2484 - accuracy: 0.9440
# Epoch 35/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.2367 - accuracy: 0.9640
# Epoch 36/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.2256 - accuracy: 0.9800
# Epoch 37/60
# 500/500 [==============================] - 0s 66us/step - loss: 0.2158 - accuracy: 0.9860
# Epoch 38/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.2058 - accuracy: 0.9860
# Epoch 39/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.1965 - accuracy: 0.9900
# Epoch 40/60
# 500/500 [==============================] - 0s 64us/step - loss: 0.1874 - accuracy: 0.9940
# Epoch 41/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.1791 - accuracy: 0.9940
# Epoch 42/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.1711 - accuracy: 0.9940
# Epoch 43/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.1634 - accuracy: 0.9960
# Epoch 44/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.1560 - accuracy: 0.9960
# Epoch 45/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.1491 - accuracy: 0.9960
# Epoch 46/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.1420 - accuracy: 0.9960
# Epoch 47/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.1351 - accuracy: 0.9960
# Epoch 48/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.1282 - accuracy: 0.9960
# Epoch 49/60
# 500/500 [==============================] - 0s 64us/step - loss: 0.1211 - accuracy: 0.9960
# Epoch 50/60
# 500/500 [==============================] - 0s 64us/step - loss: 0.1147 - accuracy: 0.9960
# Epoch 51/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.1080 - accuracy: 0.9960
# Epoch 52/60
# 500/500 [==============================] - 0s 64us/step - loss: 0.1020 - accuracy: 0.9960
# Epoch 53/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.0965 - accuracy: 0.9960
# Epoch 54/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.0913 - accuracy: 0.9960
# Epoch 55/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.0866 - accuracy: 0.9960
# Epoch 56/60
# 500/500 [==============================] - 0s 62us/step - loss: 0.0823 - accuracy: 0.9960
# Epoch 57/60
# 500/500 [==============================] - 0s 58us/step - loss: 0.0783 - accuracy: 0.9980
# Epoch 58/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.0746 - accuracy: 0.9980
# Epoch 59/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.0712 - accuracy: 0.9980
# Epoch 60/60
# 500/500 [==============================] - 0s 60us/step - loss: 0.0682 - accuracy: 0.9980

# %%
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('Acc')
plt.legend(['Accuracy'])
plt.title('Accuracy')
# Out:
# Text(0.5, 1.0, 'Accuracy')

# %%
plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['loss'])
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def plot_decision_boundary(X,y,model):
    x_span = np.linspace(min(X[:,0]) - 1,max(X[:,0]) + 0.25)
    y_span = np.linspace(min(X[:,1]) - 1, max(X[:,1]) + 0.25)
    xx,yy = np.meshgrid(x_span, y_span)
    xx_, yy_ = xx.ravel() , yy.ravel()
    grid = np.c_[xx_,yy_]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx,yy,z)

# %%
plot_decision_boundary(X,y,model)
plt.scatter(X[:n_pts,0], X[:n_pts,1])
plt.scatter(X[n_pts:,0], X[n_pts:,1])

x, y = 0.1, 0.0
point = np.array([[x,y]])
prediction = model.predict(point)
plt.plot([x],[y], marker = 'o', markersize = 10,  color = 'red')
print ('prediction is"', prediction)
# Out:
# prediction is" [[0.9638143]]
